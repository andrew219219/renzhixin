# %%
import pandas as pd

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
def search_keyword(input_dataframe, key_word):
    for col_index, col_seria in input_dataframe.items():
        for row_index, row_value in col_seria.items():
            value_no_space = str(row_value).replace(' ', '')
            if value_no_space == key_word:
                return row_index, col_index
    print('find nothing!!!')

# %%
# 在指定dataframe里查找特定关键字对应的行列单元格数据
def fetch_content_by_rkck(input_dataframe, row_keyword, column_keyword):
    row_index = search_keyword(input_dataframe, row_keyword)[0]
    column_index = search_keyword(input_dataframe, column_keyword)[1]
    return input_dataframe.iloc[row_index, column_index]

# %% [markdown]
# ### 获取管理费用-审定表-合计

# %%
sdb_df = pd.read_excel('../data/SI 管理费用.xls', sheet_name='审定表', header=None)

# %%
glfy_sdb_hj = fetch_content_by_rkck(sdb_df, '合计', '审定发生额')
glfy_sdb_hj
# Out:
# 635691.8

# %% [markdown]
# ### 获取管理费用-审定表-明细

# %%
mx_df = pd.read_excel('../data/SI 管理费用.xls', sheet_name='明细表', header=None)

# %%
search_keyword(mx_df, "上级科目名称")
# Out:
# (5, 1)

# %%
mx_df = pd.read_excel('../data/SI 管理费用.xls', sheet_name='明细表', header=None)

# %%
first_cell_position = search_keyword(mx_df, '上级科目名称')

# %%
mx_df_1 = mx_df[mx_df.index >= first_cell_position[0]]
mx_df_1
# Out:
#              0               1         2     3         4         5         6   \
# 5           NaN          上级科目名称     项   目  借贷方向        1月        2月        3月
# 6           NaN             NaN       NaN   NaN       NaN       NaN       NaN
# 7           NaN          上级科目名称      科目名称  借贷方向     1月发生额     2月发生额     3月发生额
# 8                           NaN       NaN   NaN       NaN       NaN       NaN
# 9   1:K55020101       \管理费用\办公费      办公用品     借     87.15         0         0
# 10  1:K55020102       \管理费用\办公费       资料费     借         0         0         0
# 11  1:K55020103       \管理费用\办公费     其他办公费     借         0         0       282
# 12  1:K55020104       \管理费用\办公费       通讯费     借         0    586.03     72.97
# 13    1:K550202           \管理费用     市内交通费     借       827         0         0
# 14  1:K55020301  \管理费用\机动车运行维护费  停车、过路过桥费     借         0         0         0
# 15  1:K55020302  \管理费用\机动车运行维护费       维修费     借         0         0         0
# ...
